# %%
import pandas as pd
import numpy as np
import seaborn as sns
import plotly.express as plx
import matplotlib.pyplot as plt

# %%
df= pd.read_csv('/content/drive/MyDrive/Projetos/Pivic/dados/Dados/epidemiologia dengue cg/AnyConv.com__2023_SI_DENGON2642313_00.csv')
pd.set_option('display.max_columns', None)
df.head()
# Out:
#    NU_NOTIFIC,C,7  TP_NOT,C,1 ID_AGRAVO,C,5 DT_NOTIFIC,D  SEM_NOT,C,6  \
# 0          590009           2           A90     04/28/23       202317
# 1         7632361           2           A90     05/03/23       202318
# 2         2014789           2           A90     04/11/23       202315
# 3         2013459           2           A90     04/15/23       202315
# 4           80800           2           A90     01/02/23       202301
#
#    NU_ANO,C,4  SG_UF_NOT,C,2  ID_MUNICIP,C,6  ID_REGIONA,C,8  ID_UNIDADE,C,7  \
# 0        2023             35          350840            1342         2031779
# 1        2023             41          410830            1363         2593904
# 2        2023             24          240810            1416         7408765
# 3        2023             24          240810            1416         9361936
# 4        2023             25          250400            1421         7052251
#
#   DT_SIN_PRI,D  SEM_PRI,C,6 DT_NASC,D  SOUNDEX,C,70  NU_IDADE_N,N,4,0  \
# ...

# %%
df['SOROTIPO,C,1'].isnull().sum()
# Out:
# np.int64(708)

# %%
classificacao={
    5: 'DESCARTADO',
    10: 'DENGUE',
    11: 'DENGUE C/ ALARME',
    12: 'DENGUE GRAVE',
    13: 'CHIKUNGUNYA'
}
df['CLASSI_FIN,C,2']=df['CLASSI_FIN,C,2'].replace(classificacao)

# %%
sorotipos={
    1:'DENV 1',
    2: 'DENV 2',
    3: 'DENV 3',
    4: 'DENV 4'
}
df['SOROTIPO,C,1']=df['SOROTIPO,C,1'].replace(sorotipos)

# %%
df.shape
# Out:
# (708, 146)

# %%
df.shape
# Out:
# (708, 146)

# %%
df.describe()
# Out:
#        NU_NOTIFIC,C,7  TP_NOT,C,1    SEM_NOT,C,6  NU_ANO,C,4  SG_UF_NOT,C,2  \
# count    7.080000e+02       708.0     708.000000       708.0     708.000000
# mean     1.458242e+05         2.0  202324.201977      2023.0      25.045198
# std      6.245415e+05         0.0      12.941393         0.0       0.747039
# min      2.300000e+01         2.0  202301.000000      2023.0      24.000000
# 25%      7.897875e+04         2.0  202315.000000      2023.0      25.000000
# 50%      8.049550e+04         2.0  202322.000000      2023.0      25.000000
# 75%      8.125800e+04         2.0  202333.000000      2023.0      25.000000
# max      8.666392e+06         2.0  202352.000000      2023.0      41.000000
#
#        ID_MUNICIP,C,6  ID_REGIONA,C,8  ID_UNIDADE,C,7    SEM_PRI,C,6  \
# count      708.000000      708.000000    7.080000e+02     708.000000
# mean    250860.310734     1420.738701    6.304770e+06  202320.779661
# std       7493.937100        6.720386    1.890151e+06      65.438502
# ...

# %%
df.isnull().sum()
# Out:
# NU_NOTIFIC,C,7       0
# TP_NOT,C,1           0
# ID_AGRAVO,C,5        0
# DT_NOTIFIC,D         0
# SEM_NOT,C,6          0
#                   ...
# NU_LOTE_H,C,7      708
# CS_FLXRET,C,1        0
# FLXRECEBI,C,7      708
# IDENT_MICR,C,50      0
# MIGRADO_W,C,1      708
# Length: 146, dtype: int64

# %%
#corrigindo colunas para entender o que significam e ver distribuição de valores

df['CS_RACA,C,1'] = df['CS_RACA,C,1'].replace({
    1: 'BRANCO',
    2: 'PRETO',
    3: 'AMARELO',
    4: 'PARDO',
    5: 'INDIGENA',
    9: 'IGNORADO'
})

generos={
    'M': 'HOMEM',
    'F': 'MULHER'
}
df['CS_SEXO,C,1']=df['CS_SEXO,C,1'].replace(generos)



escolaridade={
    0: 'ANALFABETO',
    1: 'PRIMARIO INCOMPLETO',
    2: 'PRIMARIO COMPLETO',
    3: '1 GRAU INCOMPLETO',
    4: 'FUNDAMENTAL COMPLETO',
    5: 'ENSINO MÉDIO INCOMPLETO',
    6: 'ENSINO MÉDIO COMPLETO',
    7: 'SUPERIOR INCOMPLETO',
    8: 'SUPERIOR COMPLETO',
    9: 'IGNORADO',
    10: 'NÃO SE APLICA'
}
df['CS_ESCOL_N,C,2']=df['CS_ESCOL_N,C,2'].replace(escolaridade)

# %%
np.unique(df['CS_RACA,C,1'].astype(str),return_counts=True)
# Out:
# (array(['AMARELO', 'BRANCO', 'IGNORADO', 'PARDO'], dtype=object),
#  array([  9,   9,   6, 684]))

# %%
np.unique(df['CS_SEXO,C,1'].astype(str), return_counts= True)
# Out:
# (array(['HOMEM', 'MULHER'], dtype=object), array([312, 396]))

# %%
#ajeitando parâmetros de data
df['DT_NOTIFIC,D'] = pd.to_datetime(df['DT_NOTIFIC,D'], format='%m/%d/%y')
df['MES DO CASO'] = df['DT_NOTIFIC,D'].dt.month

# %%
meses = {
    1: 'Janeiro',
    2: 'Fevereiro',
    3: 'Março',
    4: 'Abril',
    5: 'Maio',
    6: 'Junho',
    7: 'Julho',
    8: 'Agosto',
    9: 'Setembro',
    10: 'Outubro',
    11: 'Novembro',
    12: 'Dezembro'
}
df['MES DO CASO'] = df['MES DO CASO'].replace(meses)

# %%
df['MES DO CASO'].astype(str).value_counts()
# Out:
# MES DO CASO
# Abril        138
# Junho         96
# Maio          76
# Março         74
# Agosto        57
# Julho         55
# Dezembro      44
# Setembro      37
# Outubro       35
# Novembro      34
# Janeiro       32
# Fevereiro     30
# Name: count, dtype: int64

# %%
#trazendo os meses para estações para entender a distribuição dos casos

estacoes_por_mes={
    'Dezembro' : 'VERAO',
    'Janeiro': 'VERAO',
    'Fevereiro': 'VERAO',
    'Março': 'VERAO',
    'Abril': 'OUTONO',
    'Maio': 'OUTONO',
    'Junho': 'OUTONO',
    'Julho': 'INVERNO',
    'Agosto': 'INVERNO',
    'Setembro': 'INVERNO',
    'Outubro': 'PRIMAVERA',
    'Novembro': 'PRIMAVERA'
}
df['ESTACAO POR CASO']=df['MES DO CASO'].replace(estacoes_por_mes)

# %%
df['ESTACAO POR CASO'].astype(str).value_counts()
# Out:
# ESTACAO POR CASO
# OUTONO       310
# VERAO        180
# INVERNO      149
# PRIMAVERA     69
# Name: count, dtype: int64

# %%
df.rename(columns={
    'DT_NOTIFIC,D': 'DATA REGISTRO',
    'CS_SEXO,C,1': 'SEXO DO PACIENTE',
    'CS_RACA,C,1': 'RAÇA',
    'CS_ESCOL_N,C,2': 'GRAU ESCOLARIDADE',
    'NM_BAIRRO,C,60': 'BAIRRO',
    'CS_ZONA,C,1': 'ZONA',
    'ID_UNIDADE,C,7': 'UNIDADE DE ATENDIMENTO',
    'DT_NASC,D': 'DATA DE NASCIMENTO',
    'CLASSI_FIN,C,2': 'CLASS DOENCA',
    'SEM_PRI,C,6': 'SEMANA EPDM',
    'DT_SIN_PRI,D': 'DATA PRIMEIROS SINTOMAS',
    'SOROTIPO,C,1': 'SOROTIPO'
},inplace=True)

# %%
df['DATA DE NASCIMENTO'] = pd.to_datetime(df['DATA DE NASCIMENTO'], format='%m/%d/%y', errors='coerce')

# Correcting years that are in the future (e.g., '25' interpreted as 2025 instead of 1925)
def adjust_year(date_series):
    current_year = pd.Timestamp.now().year
    adjusted_dates = []
    for date in date_series:
        if pd.isna(date):
            adjusted_dates.append(pd.NaT)
            continue
        if date.year > current_year:
            adjusted_dates.append(date - pd.DateOffset(years=100))
        else:
            adjusted_dates.append(date)
    return pd.Series(adjusted_dates, index=date_series.index)

df['DATA DE NASCIMENTO'] = adjust_year(df['DATA DE NASCIMENTO'])

# Calculate age in years
df['IDADE EM ANOS'] = (df['DATA REGISTRO'] - df['DATA DE NASCIMENTO']).dt.days / 365.25

# Round the age to the nearest integer
df['IDADE EM ANOS'] = df['IDADE EM ANOS'].round().astype('Int64')

# %%
df_final2023 = df[['IDADE EM ANOS', 'SEXO DO PACIENTE','RAÇA','ESTACAO POR CASO','MES DO CASO','GRAU ESCOLARIDADE','BAIRRO','ZONA','UNIDADE DE ATENDIMENTO','DATA REGISTRO', 'CLASS DOENCA','SEMANA EPDM', 'DATA PRIMEIROS SINTOMAS','SOROTIPO']]

# %%
df_final2023
# Out:
#      IDADE EM ANOS SEXO DO PACIENTE      RAÇA ESTACAO POR CASO MES DO CASO  \
# 0               36            HOMEM    BRANCO           OUTONO       Abril
# 1               63           MULHER    BRANCO           OUTONO        Maio
# 2               39            HOMEM  IGNORADO           OUTONO       Abril
# 3               34           MULHER  IGNORADO           OUTONO       Abril
# 4               20           MULHER     PARDO            VERAO     Janeiro
# ..             ...              ...       ...              ...         ...
# 703             23            HOMEM  IGNORADO            VERAO     Janeiro
# 704              9            HOMEM  IGNORADO            VERAO   Fevereiro
# 705             31           MULHER     PARDO          INVERNO    Setembro
# 706             45           MULHER  IGNORADO            VERAO    Dezembro
# 707             37            HOMEM    BRANCO            VERAO   Fevereiro
#
# ...

# %%
zonas={
    1: 'URBANA',
    2: 'RURAL',
    3: 'PERIURBANA'
}
df_final2023['ZONA']=df_final2023['ZONA'].replace(zonas)
# Out:
# /tmp/ipython-input-1497138181.py:6: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
np.unique(df['BAIRRO'].astype(str),return_counts=True)
# Out:
# (array(['A', 'ACACIO FIGUEIREDO', 'ALTO BRANCO', 'ALTO CAMPINA',
#         'ALTO DA SERRA', 'ALUIZIO CAMPOS', 'ARAXA', 'BAIRRO DAS CIDADES',
#         'BAIRRO DAS NACOES', 'BAIRRO UNIVERSITARIO', 'BELA VISTA',
#         'BODOCONGO', 'BR 230', 'CASTELO BRANCO', 'CATOLE',
#         'CATOLE ZE FERREIRA', 'CENTENARIO', 'CENTRO', 'CINZA', 'CONCEICAO',
#         'CRUZEIRO', 'CUITES', 'DINAMERICA', 'ESTACAO VELHA', 'GALANTE',
#         'GLORIA', 'ITARARE', 'JARDIM CONTINENTAL', 'JARDIM EUROPA',
#         'JARDIM PAULISTANO', 'JARDIM QUARENTA', 'JARDIM TAVARES',
#         'JENIPAPO', 'JEREMIAS', 'JOSE PINHEIRO', 'JURACI PALHANO',
#         'LAURITZEN', 'LIBERDADE', 'LIGEIRO', 'LOUZEIRO', 'MALVINAS',
#         'MALVINAS I', 'MARIA DA LUZ', 'MIRANTE', 'MONTE CASTELO',
#         'MONTE SANTO', 'MUTIRAO', 'NOVA BRASILIA', 'NOVO BODOCONGO',
#         'NOVO CRUZEIRO', 'PALMEIRA', 'PEDREGAL', 'PORTAL SUDOESTE',
#         'PRATA', 'PRESIDENTE MEDICE', 'PRESIDENTE MEDICI', 'QUARENTA',
# ...

# %%
baairros={
    'A': 'ALTO BRANCO',
    'UNIVERSITARIO': 'BAIRRO UNIVERSITARIO',
    'TRES IRMAES': 'TRES IRMAS',
    'NOVO BODOCONGO': 'BODOCONGO',
    'JURACI PALHANO': 'JURACY PALHANO',
    'PRESIDENTE MEDICI': 'PRESIDENTE MEDICE',
    'SITIO SANTO ISIDIO': 'SITIO SANTO ISIDRIO',
    'SITIO SANTO IZIDRIO': 'SITIO SANTO ISIDRIO',
    'BAIRRO DAS NACOES': 'NACOES',
    'BR 230': 'ALTO BRANCO',
    'MALVINAS I': 'MALVINAS',
    'MARIA DA LUZ': 'PARQUE MARIA DA LUZ',
    'QUARENTA': 'JARDIM QUARENTA'
}

# %%
np.unique(df['UNIDADE DE ATENDIMENTO'],return_counts=True)
# Out:
# (array([   1120,  220337, 2031779, 2362287, 2362295, 2362856, 2362880,
#         2363070, 2363275, 2399989, 2428369, 2592746, 2593904, 2595443,
#         2613166, 2676060, 2792753, 2978296, 3006204, 7052251, 7113692,
#         7408765, 9068279, 9361936, 9374833, 9601473]),
#  array([  1,   3,   1,  26,  16,  14,  29,   8,   4,   1,   1,   1,   1,
#           1,   1,  14,   1,   1,   1, 517,  41,   1,   1,   1,  19,   3]))

# %%
unidades={
    220337: "HOSPITAL DE CLINICAS DE CAMPINA GRANDE",
    2362287: "INSTITUTO DE SAUDE ELPIDIO DE ALMEIDA ISEA",
    2362295: "SERVICO MUNICIPAL CAMPINA GRANDE REGIONAL SAUDE",
    2362856: "HOSPITAL DE EMERGENCIA E TRAUMA DOM LUIZ GONZAGA FERNANDES",
    2362880: "HOSPITAL MUNICIPAL DR EDGLEY",
    2363070: "HOSPITAL MUNICIPAL PEDRO I",
    2363275: "VIGILANCIA EPIDEMIOLOGICA DE CAMPINA GRANDE",
    2595443: "UBS HORACINA DE ALMEIDA",
    2676060: "HOSPITAL UNIVERSITARIO ALCIDES CARNEIRO",
    2792753: "UBS ANTONIO VIRGILIO BRASILEIRO SILVA",
    2978296: "UBS JOSE BEZERRA PIMENTEL",
    7052251: "UPA 24 HORAS DR MAIA",
    7113692: "HOSPITAL MUNICIPAL DR SEVERINO BEZERRA DE CARVALHO",
    9374833: "UPA 24 HORAS DR ADHEMAR DANTAS"
}
df_final2023['UNIDADE DE ATENDIMENTO']=df['UNIDADE DE ATENDIMENTO'].replace(unidades)
# Out:
# /tmp/ipython-input-331774241.py:17: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
# 1. Dicionário Completo (Campina Grande + Externos identificados)
unidades = {
    # --- Campina Grande ---
    220337: "HOSPITAL DE CLINICAS DE CAMPINA GRANDE",
    2362287: "INSTITUTO DE SAUDE ELPIDIO DE ALMEIDA ISEA",
    2362295: "SERVICO MUNICIPAL CAMPINA GRANDE REGIONAL SAUDE",
    2362856: "HOSPITAL DE EMERGENCIA E TRAUMA DOM LUIZ GONZAGA FERNANDES",
    2362880: "HOSPITAL MUNICIPAL DR EDGLEY",
    2363070: "HOSPITAL MUNICIPAL PEDRO I",
    2363275: "VIGILANCIA EPIDEMIOLOGICA DE CAMPINA GRANDE",
    2595443: "UBS HORACINA DE ALMEIDA",
    2676060: "HOSPITAL UNIVERSITARIO ALCIDES CARNEIRO",
    2792753: "UBS ANTONIO VIRGILIO BRASILEIRO SILVA",
    2978296: "UBS JOSE BEZERRA PIMENTEL",
    3006204: "CLINICA SANTA CLARA",
    7052251: "UPA 24 HORAS DR MAIA (ALTO BRANCO)",
    7113692: "HOSPITAL MUNICIPAL DR SEVERINO BEZERRA DE CARVALHO",
    9374833: "UPA 24 HORAS DR ADHEMAR DANTAS (DINAMERICA)",

    # --- Externos / Outras Cidades ---
    2031779: "UPA 24H ANTONIO BARADEL (SP)",
    2399989: "HOSPITAL GERAL DA PARAIBA (JOÃO PESSOA)",
    2428369: "CASA DE SAUDE SANTA EFIGENIA (PE)",
    2592746: "HOSP MATERNIDADE FLAVIO RIBEIRO COUTINHO (SANTA RITA)",
    2593904: "UPA 24H DR WALTER CAVALCANTI BARBOSA (PR)",
    2613166: "UBSF ZUMBI (PATOS-PB)",
    7408765: "UPA 24H ESPERANCA (RN)",
    9068279: "UPA NOROESTE II (MG)",
    9361936: "UPA 24HS CIDADE SATELITE (RN)",
    9601473: "UPA BANCARIOS (JOÃO PESSOA)",

    # --- Erros ---
    1120: "CODIGO INVALIDO (ERRO DE REGISTRO)"
}

# 2. Lista apenas com os IDs de Campina Grande para filtragem
ids_campina_grande = [
    220337, 2362287, 2362295, 2362856, 2362880, 2363070, 2363275,
    2595443, 2676060, 2792753, 2978296, 3006204, 7052251, 7113692, 9374833
]

# --- APLICAÇÃO NO DATAFRAME ---

# Certifique-se de que a coluna é numérica para bater com as chaves do dicionário
# (Se a coluna no Excel estiver como texto, remova o comentário da linha abaixo)
# df_final2023['UNIDADE DE ATENDIMENTO'] = pd.to_numeric(df_final2023['UNIDADE DE ATENDIMENTO'], errors='coerce')

# Cria a coluna de Classificação (Interno/Externo) ANTES de substituir o ID pelo nome
# Se o ID estiver na lista de Campina, é "Campina Grande", senão é "Externo/Outro"
df_final2023['ORIGEM_UNIDADE'] = np.where(
    df_final2023['UNIDADE DE ATENDIMENTO'].isin(ids_campina_grande),
    'Campina Grande',
    'Externo/Outro'
)

# Substitui os códigos pelos nomes conforme solicitado
df_final2023['UNIDADE DE ATENDIMENTO'] = df_final2023['UNIDADE DE ATENDIMENTO'].replace(unidades)

# Visualizar o resultado
# Out:
# /tmp/ipython-input-3339197991.py:50: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /tmp/ipython-input-3339197991.py:57: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
df_final2023
# Out:
#      IDADE EM ANOS SEXO DO PACIENTE      RAÇA ESTACAO POR CASO MES DO CASO  \
# 0               36            HOMEM    BRANCO           OUTONO       Abril
# 1               63           MULHER    BRANCO           OUTONO        Maio
# 2               39            HOMEM  IGNORADO           OUTONO       Abril
# 3               34           MULHER  IGNORADO           OUTONO       Abril
# 4               20           MULHER     PARDO            VERAO     Janeiro
# ..             ...              ...       ...              ...         ...
# 703             23            HOMEM  IGNORADO            VERAO     Janeiro
# 704              9            HOMEM  IGNORADO            VERAO   Fevereiro
# 705             31           MULHER     PARDO          INVERNO    Setembro
# 706             45           MULHER  IGNORADO            VERAO    Dezembro
# 707             37            HOMEM    BRANCO            VERAO   Fevereiro
#
#          GRAU ESCOLARIDADE             BAIRRO    ZONA  \
# ...

# %%
df_final2023 = df_final2023[df_final2023['CLASS DOENCA'] != 'DESCARTADO']
df_final2023 = df_final2023[df_final2023['CLASS DOENCA'] != 'CHIKUNGUNYA']
df_final2023 = df_final2023[df_final2023['CLASS DOENCA'] != '8']

# %%
df_final2023['UNIDADE DE ATENDIMENTO'].value_counts()
# Out:
# UNIDADE DE ATENDIMENTO
# UPA 24 HORAS DR MAIA                                          71
# HOSPITAL MUNICIPAL DR EDGLEY                                  11
# INSTITUTO DE SAUDE ELPIDIO DE ALMEIDA ISEA                     6
# HOSPITAL MUNICIPAL DR SEVERINO BEZERRA DE CARVALHO             5
# HOSPITAL UNIVERSITARIO ALCIDES CARNEIRO                        4
# HOSPITAL DE EMERGENCIA E TRAUMA DOM LUIZ GONZAGA FERNANDES     3
# UPA BANCARIOS (JOÃO PESSOA)                                    3
# HOSPITAL MUNICIPAL PEDRO I                                     2
# SERVICO MUNICIPAL CAMPINA GRANDE REGIONAL SAUDE                1
# UPA 24H DR WALTER CAVALCANTI BARBOSA (PR)                      1
# UPA 24H ESPERANCA (RN)                                         1
# UPA 24HS CIDADE SATELITE (RN)                                  1
# UPA 24H ANTONIO BARADEL (SP)                                   1
# VIGILANCIA EPIDEMIOLOGICA DE CAMPINA GRANDE                    1
# ...

# %%
df_final2023['BAIRRO'].value_counts()
# Out:
# BAIRRO
# CENTRO                8
# JOSE PINHEIRO         8
# ALTO BRANCO           7
# MALVINAS              6
# JEREMIAS              5
# CONCEICAO             5
# BODOCONGO             5
# MONTE SANTO           5
# CRUZEIRO              4
# VILA CABRAL           4
# NOVA BRASILIA         4
# CUITES                4
# CATOLE                3
# TRES IRMAES           3
# JARDIM CONTINENTAL    3
# PRESIDENTE MEDICE     2
# BAIRRO DAS CIDADES    2
# GLORIA                2
# NOVO BODOCONGO        2
# ALUIZIO CAMPOS        2
# ARAXA                 2
# PALMEIRA              2
# ESTACAO VELHA         2
# PEDREGAL              2
# VELAME                1
# DINAMERICA            1
# SERROTAO              1
# MONTE CASTELO         1
# SANTO ANTONIO         1
# JARDIM TAVARES        1
# CASTELO BRANCO        1
# RAMADINHA             1
# JARDIM QUARENTA       1
# NOVO CRUZEIRO         1
# UNIVERSITARIO         1
# CATOLE ZE FERREIRA    1
# ACACIO FIGUEIREDO     1
# JARDIM PAULISTANO     1
# ...

# %%
# Calculate the frequency of each neighborhood
neighborhood_frequency = df_final2023['BAIRRO'].value_counts().reset_index()
neighborhood_frequency.columns = ['Bairro', 'Frequência']

# Sort the DataFrame by frequency in descending order
neighborhood_frequency = neighborhood_frequency.sort_values(by='Frequência', ascending=False)

# Get the top N neighborhoods for better visualization (optional, adjust N as needed)
# For now, let's display all, but if there are too many, we might limit it.
# neighborhood_frequency_top = neighborhood_frequency.head(20)

# Create the bar chart
fig = plx.bar(
    neighborhood_frequency,
    x='Bairro',
    y='Frequência',
    title='Frequência de Casos por Bairro',
    labels={'Bairro': 'Bairro', 'Frequência': 'Número de Casos'},
    color_discrete_sequence=plx.colors.qualitative.Pastel
)

fig.update_layout(
    xaxis_title='Bairro',
    yaxis_title='Número de Casos',
    xaxis_tickangle=-45 # Rotate x-axis labels for better readability
)

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
df_final2023['SEXO DO PACIENTE'].value_counts()
# Out:
# SEXO DO PACIENTE
# MULHER    60
# HOMEM     53
# Name: count, dtype: int64

# %%
df_final2023['ESTACAO POR CASO'].value_counts()
# Out:
# ESTACAO POR CASO
# OUTONO       82
# VERAO        15
# INVERNO      14
# PRIMAVERA     2
# Name: count, dtype: int64

# %%
df_final2023['ZONA'].value_counts()
# Out:
# ZONA
# URBANA    110
# 9.0         2
# Name: count, dtype: int64

# %%
df_final2023['RAÇA'].replace('IGNORADO','PARDO',inplace=True)
df_final2023['RAÇA'].value_counts()
# Out:
# /tmp/ipython-input-2101784120.py:1: FutureWarning:
#
# A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
# RAÇA
# PARDO     109
# BRANCO      4
# Name: count, dtype: int64

# %%
df_final2023['GRAU ESCOLARIDADE'].replace('IGNORADO','ENSINO MÉDIO COMPLETO',inplace=True)

df_final2023['GRAU ESCOLARIDADE'].value_counts()
# Out:
# /tmp/ipython-input-1441659012.py:1: FutureWarning:
#
# A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
# GRAU ESCOLARIDADE
# ENSINO MÉDIO COMPLETO      99
# NÃO SE APLICA               5
# ENSINO MÉDIO INCOMPLETO     1
# SUPERIOR COMPLETO           1
# 1 GRAU INCOMPLETO           1
# PRIMARIO INCOMPLETO         1
# Name: count, dtype: int64

# %%
df_final2023['IDADE EM ANOS'].value_counts()
# Out:
# IDADE EM ANOS
# 22    10
# 39     6
# 45     5
# 34     4
# 26     4
# 28     4
# 33     4
# 42     4
# 43     4
# 31     3
# 35     3
# 27     3
# 20     3
# 30     3
# 46     3
# 9      3
# 25     3
# 41     2
# 36     2
# 44     2
# 32     2
# 60     2
# 54     2
# 29     2
# 24     2
# 52     2
# 37     2
# 63     1
# 50     1
# 38     1
# 62     1
# 6      1
# 7      1
# 4      1
# 8      1
# 51     1
# -3     1
# 76     1
# 57     1
# 40     1
# 17     1
# 11     1
# 15     1
# 21     1
# 53     1
# 5      1
# 18     1
# 48     1
# 0      1
# 19     1
# 23     1
# Name: count, dtype: Int64

# %%
df_final2023['DATA REGISTRO'] = df_final2023['DATA REGISTRO'].dt.year

# %%
df_final2023['SEMANA EPDM'] = df_final2023['SEMANA EPDM'].astype(str).str[-2:]

# %%
df_final2023['BAIRRO'].fillna('CENTRO',inplace=True)
np.unique(df_final2023['BAIRRO'].astype(str),return_counts=True)
# Out:
# /tmp/ipython-input-990864343.py:1: FutureWarning:
#
# A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
# (array(['ACACIO FIGUEIREDO', 'ALTO BRANCO', 'ALUIZIO CAMPOS', 'ARAXA',
#         'BAIRRO DAS CIDADES', 'BODOCONGO', 'CASTELO BRANCO', 'CATOLE',
#         'CATOLE ZE FERREIRA', 'CENTENARIO', 'CENTRO', 'CONCEICAO',
#         'CRUZEIRO', 'CUITES', 'DINAMERICA', 'ESTACAO VELHA', 'GLORIA',
#         'JARDIM CONTINENTAL', 'JARDIM PAULISTANO', 'JARDIM QUARENTA',
#         'JARDIM TAVARES', 'JEREMIAS', 'JOSE PINHEIRO', 'MALVINAS',
# ...

# %%
df_final2023['GRAU ESCOLARIDADE'].fillna('ENSINO MÉDIO COMPLETO',inplace=True)
# Out:
# /tmp/ipython-input-3981993775.py:1: FutureWarning:
#
# A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.

# %%
np.unique(df_final2023['CLASS DOENCA'].astype(str),return_counts=True)
# Out:
# (array(['8', 'DENGUE'], dtype=object), array([96, 17]))

# %%
df_final2023.head()
# Out:
#     IDADE EM ANOS SEXO DO PACIENTE    RAÇA ESTACAO POR CASO MES DO CASO  \
# 0              36            HOMEM  BRANCO           OUTONO       Abril
# 1              63           MULHER  BRANCO           OUTONO        Maio
# 2              39            HOMEM   PARDO           OUTONO       Abril
# 3              34           MULHER   PARDO           OUTONO       Abril
# 20             62           MULHER   PARDO            VERAO     Janeiro
#
#         GRAU ESCOLARIDADE             BAIRRO    ZONA  \
# 0   ENSINO MÉDIO COMPLETO  PRESIDENTE MEDICE  URBANA
# 1   ENSINO MÉDIO COMPLETO        ALTO BRANCO  URBANA
# 2   ENSINO MÉDIO COMPLETO           SERROTAO  URBANA
# 3   ENSINO MÉDIO COMPLETO          BODOCONGO     9.0
# 20  ENSINO MÉDIO COMPLETO          CONCEICAO  URBANA
#
#                        UNIDADE DE ATENDIMENTO  DATA REGISTRO CLASS DOENCA  \
# 0                UPA 24H ANTONIO BARADEL (SP)           2023       DENGUE
# ...

# %%
df_final2023 = df_final2023[df_final2023['CLASS DOENCA'].astype(str) != '8']
np.unique(df_final2023['CLASS DOENCA'].astype(str),return_counts=True)
# Out:
# (array(['DENGUE'], dtype=object), array([17]))

# %%
df_final2023.shape
# Out:
# (17, 15)

# %%
df_final2023['ZONA'].replace(9.0,'URBANA',inplace=True)
# Out:
# /tmp/ipython-input-247572789.py:1: FutureWarning:
#
# A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.

# %%
df_final2023.to_csv('dengue2023_tratado.csv',index=False)
