# %%
import pandas as pd
import numpy as np
import seaborn as sns
import plotly.express as plx
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('/content/drive/MyDrive/Projetos/Pivic/dados/Dados/epidemiologia dengue cg/AnyConv.com__2021_SI_DENGON2642316_00.csv')
pd.set_option('display.max_columns', None)
df.head()
# Out:
#    NU_NOTIFIC,C,7  TP_NOT,C,1 ID_AGRAVO,C,5 DT_NOTIFIC,D  SEM_NOT,C,6  \
# 0         8651937           2           A90     09/16/21       202137
# 1         7241208           2           A90     06/18/21       202124
# 2         7358375           2           A90     05/31/21       202122
# 3         7016773           2           A90     04/04/21       202114
# 4         1678341           2           A90     01/01/21       202053
#
#    NU_ANO,C,4  SG_UF_NOT,C,2  ID_MUNICIP,C,6  ID_REGIONA,C,8  ID_UNIDADE,C,7  \
# 0        2021             35          355030          1331.0          248991
# 1        2021             35          355030          1331.0          248991
# 2        2021             35          355030          1331.0          248991
# 3        2021             35          354980          1354.0         2052474
# 4        2021             24          240810          1416.0         7408765
#
#   DT_SIN_PRI,D  SEM_PRI,C,6 DT_NASC,D  SOUNDEX,C,70  NU_IDADE_N,N,4,0  \
# ...

# %%
classificacao={
    5: 'DESCARTADO',
    10: 'DENGUE',
    11: 'DENGUE C/ ALARME',
    12: 'DENGUE GRAVE',
    13: 'CHIKUNGUNYA'
}
df['CLASSI_FIN,C,2']=df['CLASSI_FIN,C,2'].replace(classificacao)

# %%
np.unique(df['CS_RACA,C,1'],return_counts=True)
# Out:
# (array([1, 2, 3, 4, 9]), array([ 24,   7,   1, 226,  14]))

# %%
df.shape
# Out:
# (272, 146)

# %%
df=df.dropna(axis=1,how='all')

# %%
df.shape
# Out:
# (272, 99)

# %%
df['CS_RACA,C,1'] = df['CS_RACA,C,1'].replace({
    1: 'BRANCO',
    2: 'PRETO',
    3: 'AMARELO',
    4: 'PARDO',
    5: 'INDIGENA',
    9: 'IGNORADO'
})
# Correcting the problematic assignment from qZsae-tpZGZL here
df['CS_RACA,C,1'] = df['CS_RACA,C,1'].replace('IGNORADO','PARDO')

generos={
    'M': 'HOMEM',
    'F': 'MULHER'
}
df['CS_SEXO,C,1']=df['CS_SEXO,C,1'].replace(generos)


escolaridade={
    0: 'ANALFABETO',
    1: 'PRIMARIO INCOMPLETO',
    2: 'PRIMARIO COMPLETO',
    3: '1 GRAU INCOMPLETO',
    4: 'FUNDAMENTAL COMPLETO',
    5: 'ENSINO MÉDIO INCOMPLETO',
    6: 'ENSINO MÉDIO COMPLETO',
    7: 'SUPERIOR INCOMPLETO',
    8: 'SUPERIOR COMPLETO',
    9: 'IGNORADO',
    10: 'NÃO SE APLICA'
}
df['CS_ESCOL_N,C,2']=df['CS_ESCOL_N,C,2'].replace(escolaridade)

# %%
np.unique(df['CS_RACA,C,1'].astype(str),return_counts=True)
# Out:
# (array(['AMARELO', 'BRANCO', 'PARDO', 'PRETO'], dtype=object),
#  array([  1,  24, 240,   7]))

# %%
np.unique(df['CS_RACA,C,1'].astype(str),return_counts=True)
# Out:
# (array(['AMARELO', 'BRANCO', 'PARDO', 'PRETO'], dtype=object),
#  array([  1,  24, 240,   7]))

# %%
# This cell was causing the error and its logic has been moved to 'vrtEchcSY5Ui'.

# %%
np.unique(df['CS_SEXO,C,1'].astype(str), return_counts= True)
# Out:
# (array(['HOMEM', 'MULHER'], dtype=object), array([ 97, 175]))

# %%
df['DT_NOTIFIC,D'] = pd.to_datetime(df['DT_NOTIFIC,D'], format='%m/%d/%y')
df['MES DO CASO'] = df['DT_NOTIFIC,D'].dt.month

# %%
meses = {
    1: 'Janeiro',
    2: 'Fevereiro',
    3: 'Março',
    4: 'Abril',
    5: 'Maio',
    6: 'Junho',
    7: 'Julho',
    8: 'Agosto',
    9: 'Setembro',
    10: 'Outubro',
    11: 'Novembro',
    12: 'Dezembro'
}
df['MES DO CASO'] = df['MES DO CASO'].replace(meses)

# %%
estacoes_por_mes={
    'Dezembro' : 'VERAO',
    'Janeiro': 'VERAO',
    'Fevereiro': 'VERAO',
    'Março': 'VERAO',
    'Abril': 'OUTONO',
    'Maio': 'OUTONO',
    'Junho': 'OUTONO',
    'Julho': 'INVERNO',
    'Agosto': 'INVERNO',
    'Setembro': 'INVERNO',
    'Outubro': 'PRIMAVERA',
    'Novembro': 'PRIMAVERA'
}
df['ESTACAO POR CASO']=df['MES DO CASO'].replace(estacoes_por_mes)

# %%
df.rename(columns={
    'DT_NOTIFIC,D': 'DATA REGISTRO',
    'CS_SEXO,C,1': 'SEXO DO PACIENTE',
    'CS_RACA,C,1': 'RAÇA',
    'CS_ESCOL_N,C,2': 'GRAU ESCOLARIDADE',
    'NM_BAIRRO,C,60': 'BAIRRO',
    'CS_ZONA,C,1': 'ZONA',
    'ID_UNIDADE,C,7': 'UNIDADE DE ATENDIMENTO',
    'DT_NASC,D': 'DATA DE NASCIMENTO',
    'CLASSI_FIN,C,2': 'CLASS DOENCA',
    'SEM_PRI,C,6': 'SEMANA EPDM',
    'DT_SIN_PRI,D': 'DATA PRIMEIROS SINTOMAS',
    'SOROTIPO,C,1': 'SOROTIPO'

},inplace=True)

# %%
np.unique(df['BAIRRO'].astype(str),return_counts=True)
# Out:
# (array(['ACACIO FIGUEIREDO', 'ALAMEDA', 'ALTO BRANCO', 'ALUISIO CAMPOS',
#         'ARAXA', 'BAIRRO DAS CIDADES', 'BAIRRO DAS NACOES',
#         'BAIRRO UNIVERSITARIO', 'BELA VISTA', 'BODOCONGO', 'BODOCONGO III',
#         'BR 104 KM 119', 'CAMPINA GRANDE', 'CATOLE', 'CENTENARIO',
#         'CENTRO', 'CIDADES', 'CINZA', 'CONJ SEVERINO CABRAL', 'CRUZEIRO',
#         'CUITES', 'DINAMERICA', 'GALANTE', 'ITARARE', 'JARDIM PAULISTANO',
#         'JARDIM QUARENTA', 'JARDIM TAVARES', 'JEREMIAS', 'JOSE PINHEIRO',
#         'LAGOA DE DENTRO', 'LIBERDADE', 'LIGEIRO', 'LOUZEIRO', 'MALVINAS',
#         'MIRANTE', 'MONTE CASTELO', 'MONTE SANTO', 'NOVA BRASILIA',
#         'NOVO CRUZEIRO', 'NOVO HORIZONTE', 'PALMEIRA', 'PEDREGAL',
#         'PORTAL SUDOESTE', 'PRATA', 'PRESIDENTE MEDICE', 'QUARENTA',
#         'RAMADINHA', 'ROCHA CAVALCANTE', 'SANDRA CAVALCANTE', 'SANTA CRUZ',
#         'SANTA ROSA', 'SANTA TEREZINHA', 'SANTA TREZINHA', 'SANTO ANTONIO',
# ...

# %%
bairros={
    'ALUISIO CAMPOS': 'ALUIZIO CAMPOS',
    'BAIRRO DAS NACOES': 'NACOES',
    'BODOCONGO III': 'NOVO BODOCONGO',
    'CIDADES': 'BAIRRO DAS CIDADES',
    'NOVO CRUZEIRO': 'CRUZEIRO',
    'QUARENTA': 'JARDIM QUARENTA',
    'SÒO JOSÚ': 'SAO JOSE',
    'TRÛS IRMAS': 'TRES IRMAS',
    'BR 104 KM 119': 'JURACY PALHANO'
}

# %%
df['DATA DE NASCIMENTO'] = pd.to_datetime(df['DATA DE NASCIMENTO'], format='%m/%d/%y', errors='coerce')

# Correcting years that are in the future (e.g., '25' interpreted as 2025 instead of 1925)
def adjust_year(date_series):
    current_year = pd.Timestamp.now().year
    adjusted_dates = []
    for date in date_series:
        if pd.isna(date):
            adjusted_dates.append(pd.NaT)
            continue
        if date.year > current_year:
            adjusted_dates.append(date - pd.DateOffset(years=100))
        else:
            adjusted_dates.append(date)
    return pd.Series(adjusted_dates, index=date_series.index)

df['DATA DE NASCIMENTO'] = adjust_year(df['DATA DE NASCIMENTO'])

# Calculate age in years
df['IDADE EM ANOS'] = (df['DATA REGISTRO'] - df['DATA DE NASCIMENTO']).dt.days / 365.25

# Round the age to the nearest integer
df['IDADE EM ANOS'] = df['IDADE EM ANOS'].round().astype('Int64')

# %%
df_final2021 = df[['IDADE EM ANOS', 'SEXO DO PACIENTE','RAÇA','ESTACAO POR CASO','MES DO CASO','GRAU ESCOLARIDADE','BAIRRO','ZONA','UNIDADE DE ATENDIMENTO','DATA REGISTRO', 'CLASS DOENCA','SEMANA EPDM', 'DATA PRIMEIROS SINTOMAS','SOROTIPO']]

# %%
df_final2021 = df_final2021[df_final2021['CLASS DOENCA'] != 'DESCARTADO']
df_final2021 = df_final2021[df_final2021['CLASS DOENCA'] != 'CHIKUNGUNYA']
df_final2021 = df_final2021[df_final2021['CLASS DOENCA'] != 8]

# %%
df_final2021['DATA REGISTRO'] = df_final2021['DATA REGISTRO'].dt.year

# %%
df_final2021['SEMANA EPDM'] = df_final2021['SEMANA EPDM'].astype(str).str[-2:]

# %%
df_final2021['GRAU ESCOLARIDADE'].replace('IGNORADO','ENSINO MÉDIO COMPLETO',inplace=True)
# Out:
# /tmp/ipython-input-2119922578.py:1: FutureWarning:
#
# A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.

# %%
df_final2021['RAÇA'].replace('IGNORADO','PARDO',inplace=True)
# Out:
# /tmp/ipython-input-1771655403.py:1: FutureWarning:
#
# A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.

# %%
df_final2021
# Out:
#      IDADE EM ANOS SEXO DO PACIENTE    RAÇA ESTACAO POR CASO MES DO CASO  \
# 10              39           MULHER   PARDO            VERAO   Fevereiro
# 12              25           MULHER   PARDO            VERAO     Janeiro
# 28              52           MULHER  BRANCO          INVERNO       Julho
# 33              32           MULHER   PARDO          INVERNO       Julho
# 34              36           MULHER   PARDO        PRIMAVERA     Outubro
# 36              28           MULHER   PARDO          INVERNO       Julho
# 41              59           MULHER   PARDO            VERAO   Fevereiro
# 51              43            HOMEM   PARDO            VERAO       Março
# 52              26           MULHER   PARDO            VERAO   Fevereiro
# 58              25           MULHER   PRETO            VERAO       Março
# 64               6            HOMEM   PARDO           OUTONO       Junho
# 66              35           MULHER  BRANCO          INVERNO       Julho
# ...

# %%
zonas={
    1: 'URBANA',
    2: 'RURAL',
    3: 'PERIURBANA'
}
df_final2021['ZONA']=df_final2021['ZONA'].replace(zonas)
df_final2021['ZONA']=df_final2021['ZONA'].replace('nan','URBANA')

# %%
df_final2021
# Out:
#      IDADE EM ANOS SEXO DO PACIENTE    RAÇA ESTACAO POR CASO MES DO CASO  \
# 10              39           MULHER   PARDO            VERAO   Fevereiro
# 12              25           MULHER   PARDO            VERAO     Janeiro
# 28              52           MULHER  BRANCO          INVERNO       Julho
# 33              32           MULHER   PARDO          INVERNO       Julho
# 34              36           MULHER   PARDO        PRIMAVERA     Outubro
# 36              28           MULHER   PARDO          INVERNO       Julho
# 41              59           MULHER   PARDO            VERAO   Fevereiro
# 51              43            HOMEM   PARDO            VERAO       Março
# 52              26           MULHER   PARDO            VERAO   Fevereiro
# 58              25           MULHER   PRETO            VERAO       Março
# 64               6            HOMEM   PARDO           OUTONO       Junho
# 66              35           MULHER  BRANCO          INVERNO       Julho
# ...

# %%
np.unique(df_final2021['ZONA'].astype(str),return_counts=True)
# Out:
# (array(['URBANA', 'nan'], dtype=object), array([58,  1]))

# %%
df_final2021['ZONA'] = df_final2021['ZONA'].replace('nan','URBANA')

# %%
# This cell was removed as its functionality is redundant and causing errors. The df_final2021 DataFrame is created correctly in cell 'PaKONXZaZhlh' and 'ZONA' transformations are handled in 'zvMOByq9Zlc4'.

# %%
bairros={
    'ALUISIO CAMPOS': 'ALUIZIO CAMPOS',
    'BAIRRO DAS NACOES': 'NACOES',
    'BODOCONGO III': 'NOVO BODOCONGO',
    'CIDADES': 'BAIRRO DAS CIDADES',
    'NOVO CRUZEIRO': 'CRUZEIRO',
    'QUARENTA': 'JARDIM QUARENTA',
    'SÒO JOSÚ': 'SAO JOSE',
    'TRÛS IRMAS': 'TRES IRMAS',
    'BR 104 KM 119': 'JURACY PALHANO',
    'SANTA TREZINHA': 'SANTA TEREZINHA'
}
df_final2021['BAIRRO']=df_final2021['BAIRRO'].replace(bairros)

# %%
import pandas as pd
import numpy as np

unidades = {
    # --- Campina Grande (Rede Própria e Conveniada) ---
    220337:  "HOSPITAL DE CLINICAS DE CAMPINA GRANDE",
    248991:  "LABORATORIO PREANALITICA (PRIVADO)",
    2344386: "POLICLINICA MUNICIPAL DA PRATA (LIBERDADE)",
    2362201: "UBS SAO JOSE DA MATA",
    2362287: "INSTITUTO DE SAUDE ELPIDIO DE ALMEIDA ISEA",
    2362295: "SERVICO MUNICIPAL CAMPINA GRANDE REGIONAL SAUDE", # Secretaria de Saúde
    2362309: "CENTRO DE SAUDE DA LIBERDADE",
    2362627: "CAPS AD",
    2362821: "HEMOCENTRO REGIONAL DE CAMPINA GRANDE",
    2362856: "HOSPITAL DE EMERGENCIA E TRAUMA DOM LUIZ GONZAGA FERNANDES",
    2363070: "HOSPITAL MUNICIPAL PEDRO I",
    2363275: "VIGILANCIA EPIDEMIOLOGICA DE CAMPINA GRANDE",
    2595400: "UBS WESLEY CARIRI TARGINO (NOVA FLORESTA)",
    2595443: "UBS HORACINA DE ALMEIDA",
    2607123: "HOSPITAL DE OLHOS DA PARAIBA",
    2607336: "UBS UNIDADE MISTA DE GALANTE",
    2608650: "UBS RAIF RAMALHO (ACUDE NOVO)",
    2676060: "HOSPITAL UNIVERSITARIO ALCIDES CARNEIRO",
    3006204: "CLINICA SANTA CLARA",
    5053250: "UBS VELAME",
    5053269: "UBS JARDIM VERDEJANTE",
    5932416: "UBS PEDREGAL I E II",
    6267939: "CENTRO DE GENETICA MEDICA",
    7052251: "UPA 24 HORAS DR MAIA (ALTO BRANCO)",
    7113692: "HOSPITAL MUNICIPAL DR SEVERINO BEZERRA DE CARVALHO",

    # --- Externos (João Pessoa, Santa Rita, Bayeux, etc) ---
    2052474: "HOSPITAL SANTA ISABEL (JOAO PESSOA)",
    2399318: "COMPLEXO PSIQUIATRICO JULIANO MOREIRA (JOAO PESSOA)",
    2399989: "HOSPITAL GENERAL EDSON RAMALHO (JOAO PESSOA)",
    2806045: "UPA 24H DR OTAVIO PIRES (PATOS)",
    6346510: "HOSPITAL METROPOLITANO DOM JOSE MARIA PIRES (SANTA RITA)",
    6679528: "UPA 24H TIBIRI - JOSENILDO LEITE (SANTA RITA)",
    6940315: "UPA 24H DR WALDEMAR ALCANTARA (CAJAZEIRAS)",
    6962831: "UPA 24H SOBEUS (GUARABIRA)",
    7408765: "UPA 24H NOVA ESPERANCA (PARNAMIRIM-RN)",
    7646526: "UPA 24H OCEANIA (JOAO PESSOA - BESSA)",
    7742878: "UPA 24H EZEQUIEL EPIFANIO (BAYEUX)",

    # --- Erros / Indefinidos ---
    396:     "CODIGO INVALIDO (ERRO DE REGISTRO)"
}

# 2. Lista apenas com os IDs de Campina Grande (Cód Mun 250400)
ids_campina_grande = [
    220337, 248991, 2344386, 2362201, 2362287, 2362295, 2362309,
    2362627, 2362821, 2362856, 2363070, 2363275, 2595400, 2595443,
    2607123, 2607336, 2608650, 2676060, 3006204, 5053250, 5053269,
    5932416, 6267939, 7052251, 7113692
]

# --- APLICAÇÃO NO DATAFRAME ---

# (Opcional) Converter para numérico caso esteja como texto
# df_final2023['UNIDADE DE ATENDIMENTO'] = pd.to_numeric(df_final2023['UNIDADE DE ATENDIMENTO'], errors='coerce')

# 1. Cria a coluna de Classificação (Interno/Externo) baseada na lista de IDs de CG
df_final2021['ORIGEM_UNIDADE'] = np.where(
    df_final2021['UNIDADE DE ATENDIMENTO'].isin(ids_campina_grande),
    'Campina Grande',
    'Externo/Outro'
)

# 2. Substitui os códigos pelos nomes descritivos
df_final2021['UNIDADE DE ATENDIMENTO'] = df_final2021['UNIDADE DE ATENDIMENTO'].replace(unidades)

# %%
np.unique(df_final2021['UNIDADE DE ATENDIMENTO'].astype(str),return_counts=True)
# Out:
# (array(['CLINICA SANTA CLARA',
#         'HOSPITAL DE EMERGENCIA E TRAUMA DOM LUIZ GONZAGA FERNANDES',
#         'HOSPITAL GENERAL EDSON RAMALHO (JOAO PESSOA)',
#         'HOSPITAL MUNICIPAL DR SEVERINO BEZERRA DE CARVALHO',
#         'HOSPITAL MUNICIPAL PEDRO I',
#         'HOSPITAL UNIVERSITARIO ALCIDES CARNEIRO',
#         'SERVICO MUNICIPAL CAMPINA GRANDE REGIONAL SAUDE',
#         'UBS HORACINA DE ALMEIDA', 'UBS UNIDADE MISTA DE GALANTE',
#         'UBS WESLEY CARIRI TARGINO (NOVA FLORESTA)',
#         'UPA 24 HORAS DR MAIA (ALTO BRANCO)',
#         'UPA 24H DR WALDEMAR ALCANTARA (CAJAZEIRAS)',
#         'UPA 24H OCEANIA (JOAO PESSOA - BESSA)',
#         'VIGILANCIA EPIDEMIOLOGICA DE CAMPINA GRANDE'], dtype=object),
#  array([ 3,  6,  1,  4,  1, 11,  2,  1,  1,  1,  2,  3,  1, 22]))

# %%
df_final2021['UNIDADE DE ATENDIMENTO'].value_counts()
# Out:
# UNIDADE DE ATENDIMENTO
# VIGILANCIA EPIDEMIOLOGICA DE CAMPINA GRANDE                   22
# HOSPITAL UNIVERSITARIO ALCIDES CARNEIRO                       11
# HOSPITAL DE EMERGENCIA E TRAUMA DOM LUIZ GONZAGA FERNANDES     6
# HOSPITAL MUNICIPAL DR SEVERINO BEZERRA DE CARVALHO             4
# UPA 24H DR WALDEMAR ALCANTARA (CAJAZEIRAS)                     3
# CLINICA SANTA CLARA                                            3
# UPA 24 HORAS DR MAIA (ALTO BRANCO)                             2
# SERVICO MUNICIPAL CAMPINA GRANDE REGIONAL SAUDE                2
# UBS WESLEY CARIRI TARGINO (NOVA FLORESTA)                      1
# UBS HORACINA DE ALMEIDA                                        1
# HOSPITAL MUNICIPAL PEDRO I                                     1
# UBS UNIDADE MISTA DE GALANTE                                   1
# HOSPITAL GENERAL EDSON RAMALHO (JOAO PESSOA)                   1
# UPA 24H OCEANIA (JOAO PESSOA - BESSA)                          1
# Name: count, dtype: int64

# %%
df_final2021['RAÇA'].value_counts()
# Out:
# RAÇA
# PARDO     51
# BRANCO     6
# PRETO      2
# Name: count, dtype: int64

# %%
df_final2021['BAIRRO'].value_counts()
# Out:
# BAIRRO
# BODOCONGO            6
# VILA CABRAL          5
# MALVINAS             5
# CENTRO               4
# CRUZEIRO             4
# CATOLE               3
# MONTE CASTELO        3
# GALANTE              2
# PRATA                2
# RAMADINHA            2
# TRES IRMAES          2
# TAMBOR               2
# SANTA ROSA           2
# NOVO HORIZONTE       1
# ALTO BRANCO          1
# NOVA BRASILIA        1
# MONTE SANTO          1
# LOUZEIRO             1
# VELAME               1
# LIGEIRO              1
# CENTENARIO           1
# LIBERDADE            1
# JARDIM PAULISTANO    1
# JEREMIAS             1
# LAGOA DE DENTRO      1
# NACOES               1
# DINAMERICA           1
# ACACIO FIGUEIREDO    1
# Name: count, dtype: int64

# %%
neighborhood_frequency = df_final2021['BAIRRO'].value_counts().reset_index()
neighborhood_frequency.columns = ['Bairro', 'Frequência']

# Sort the DataFrame by frequency in descending order
neighborhood_frequency = neighborhood_frequency.sort_values(by='Frequência', ascending=False)

# Get the top N neighborhoods for better visualization (optional, adjust N as needed)
# For now, let's display all, but if there are too many, we might limit it.
# neighborhood_frequency_top = neighborhood_frequency.head(20)

# Create the bar chart
fig = plx.bar(
    neighborhood_frequency,
    x='Bairro',
    y='Frequência',
    title='Frequência de Casos por Bairro',
    labels={'Bairro': 'Bairro', 'Frequência': 'Número de Casos'},
    color_discrete_sequence=plx.colors.qualitative.Pastel
)

fig.update_layout(
    xaxis_title='Bairro',
    yaxis_title='Número de Casos',
    xaxis_tickangle=-45 # Rotate x-axis labels for better readability
)

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
df_final2021.shape
# Out:
# (59, 15)

# %%
sorotipos={
    1:'DENV 1',
    2: 'DENV 2',
    3: 'DENV 3',
    4: 'DENV 4'
}
df_final2021['SOROTIPO']=df_final2021['SOROTIPO'].replace(sorotipos)

# %%
df_final2021
# Out:
#      IDADE EM ANOS SEXO DO PACIENTE    RAÇA ESTACAO POR CASO MES DO CASO  \
# 10              39           MULHER   PARDO            VERAO   Fevereiro
# 12              25           MULHER   PARDO            VERAO     Janeiro
# 28              52           MULHER  BRANCO          INVERNO       Julho
# 33              32           MULHER   PARDO          INVERNO       Julho
# 34              36           MULHER   PARDO        PRIMAVERA     Outubro
# 36              28           MULHER   PARDO          INVERNO       Julho
# 41              59           MULHER   PARDO            VERAO   Fevereiro
# 51              43            HOMEM   PARDO            VERAO       Março
# 52              26           MULHER   PARDO            VERAO   Fevereiro
# 58              25           MULHER   PRETO            VERAO       Março
# 64               6            HOMEM   PARDO           OUTONO       Junho
# 66              35           MULHER  BRANCO          INVERNO       Julho
# ...

# %%
df_final2021['BAIRRO'].fillna('BODOCONGO',inplace=True)
# Out:
# /tmp/ipython-input-2117740645.py:1: FutureWarning:
#
# A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.

# %%
df_final2021['ZONA'].fillna('URBANA',inplace=True)
# Out:
# /tmp/ipython-input-368585938.py:1: FutureWarning:
#
# A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.

# %%
df_final2021['CLASS DOENCA'].value_counts()
# Out:
# CLASS DOENCA
# DENGUE              58
# DENGUE C/ ALARME     1
# Name: count, dtype: int64

# %%
df_final2021.to_csv('dengue2021_tratado.csv', index=False)
