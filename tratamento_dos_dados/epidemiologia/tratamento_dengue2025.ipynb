# %%
import pandas as pd
import numpy as np
import plotly.express as plx
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df= pd.read_csv('/content/drive/MyDrive/Pivic/dados/Dados/epidemiologia dengue cg/AnyConv.com__2025_SI_DENGON2642310_00.csv')
pd.set_option('display.max_columns', None)
df.head()
# Out:
#    NU_NOTIFIC,C,7  TP_NOT,C,1 ID_AGRAVO,C,5 DT_NOTIFIC,D  SEM_NOT,C,6  \
# 0         6902153           2           A90     02/21/25       202508
# 1           93151           2           A90     09/14/25       202538
# 2           93227           2           A90     09/23/25       202539
# 3           93254           2           A90     09/11/25       202537
# 4           93193           2           A90     09/26/25       202539
#
#    NU_ANO,C,4  SG_UF_NOT,C,2  ID_MUNICIP,C,6  ID_REGIONA,C,8  ID_UNIDADE,C,7  \
# 0        2025             41          410690            1356         2639548
# 1        2025             25          250400            1421         9374833
# 2        2025             25          250400            1421         9374833
# 3        2025             25          250400            1421         9352902
# 4        2025             25          250400            1421         7052251
#
#   DT_SIN_PRI,D  SEM_PRI,C,6 DT_NASC,D  SOUNDEX,C,70  NU_IDADE_N,N,4,0  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3050 entries, 0 to 3049
# Columns: 146 entries, NU_NOTIFIC,C,7 to MIGRADO_W,C,1
# dtypes: float64(111), int64(17), object(18)
# memory usage: 3.4+ MB

# %%
df['CLASSI_FIN,C,2']
# Out:
# 0       10.0
# 1        5.0
# 2        5.0
# 3        5.0
# 4        5.0
#         ...
# 3045     8.0
# 3046    10.0
# 3047    10.0
# 3048     5.0
# 3049     8.0
# Name: CLASSI_FIN,C,2, Length: 3050, dtype: float64

# %%
df['SEM_PRI,C,6']
# Out:
# 0       202508
# 1       202537
# 2       202539
# 3       202536
# 4       202539
#          ...
# 3045    202513
# 3046    202504
# 3047    202520
# 3048    202516
# 3049    202530
# Name: SEM_PRI,C,6, Length: 3050, dtype: int64

# %%
df['DT_SIN_PRI,D']
# Out:
# 0       02/18/25
# 1       09/13/25
# 2       09/22/25
# 3       09/06/25
# 4       09/24/25
#           ...
# 3045    03/26/25
# 3046    01/23/25
# 3047    05/13/25
# 3048    04/13/25
# 3049    07/21/25
# Name: DT_SIN_PRI,D, Length: 3050, dtype: object

# %%
classificacao={
    5: 'DESCARTADO',
    10: 'DENGUE',
    11: 'DENGUE C/ ALARME',
    12: 'DENGUE GRAVE',
    13: 'CHIKUNGUNYA'
}
df['CLASSI_FIN,C,2']=df['CLASSI_FIN,C,2'].replace(classificacao)

# %%
df['CLASSI_FIN,C,2'].value_counts()
# Out:
# CLASSI_FIN,C,2
# DESCARTADO    2830
# DENGUE         209
# 8.0              4
# Name: count, dtype: int64

# %%
df['DT_SIN_PRI,D']
# Out:
# 0       02/18/25
# 1       09/13/25
# 2       09/22/25
# 3       09/06/25
# 4       09/24/25
#           ...
# 3045    03/26/25
# 3046    01/23/25
# 3047    05/13/25
# 3048    04/13/25
# 3049    07/21/25
# Name: DT_SIN_PRI,D, Length: 3050, dtype: object

# %%
df.shape
# Out:
# (3050, 146)

# %%
df=df.dropna(axis=1, how='all')

# %%
df.shape
# Out:
# (3050, 86)

# %%
df.describe()
# Out:
#        NU_NOTIFIC,C,7  TP_NOT,C,1    SEM_NOT,C,6  NU_ANO,C,4  SG_UF_NOT,C,2  \
# count    3.050000e+03      3050.0    3050.000000      3050.0    3050.000000
# mean     1.151894e+05         2.0  202521.706557      2025.0      25.025902
# std      3.562710e+05         0.0      13.207633         0.0       0.760399
# min      2.100000e+01         2.0  202501.000000      2025.0      23.000000
# 25%      9.118750e+04         2.0  202510.000000      2025.0      25.000000
# 50%      9.199150e+04         2.0  202519.000000      2025.0      25.000000
# 75%      9.283775e+04         2.0  202534.000000      2025.0      25.000000
# max      7.040821e+06         2.0  202549.000000      2025.0      52.000000
#
#        ID_MUNICIP,C,6  ID_REGIONA,C,8  ID_UNIDADE,C,7    SEM_PRI,C,6  \
# count     3050.000000     3050.000000    3.050000e+03    3050.000000
# mean    250663.478033     1421.438689    6.979965e+06  202520.527541
# std       7639.194316       10.335263    2.957703e+06      43.921432
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3050 entries, 0 to 3049
# Data columns (total 86 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   NU_NOTIFIC,C,7    3050 non-null   int64
#  1   TP_NOT,C,1        3050 non-null   int64
#  2   ID_AGRAVO,C,5     3050 non-null   object
#  3   DT_NOTIFIC,D      3050 non-null   object
#  4   SEM_NOT,C,6       3050 non-null   int64
#  5   NU_ANO,C,4        3050 non-null   int64
#  6   SG_UF_NOT,C,2     3050 non-null   int64
#  7   ID_MUNICIP,C,6    3050 non-null   int64
#  8   ID_REGIONA,C,8    3050 non-null   int64
#  9   ID_UNIDADE,C,7    3050 non-null   int64
#  10  DT_SIN_PRI,D      3050 non-null   object
#  11  SEM_PRI,C,6       3050 non-null   int64
#  12  DT_NASC,D         3050 non-null   object
#  13  NU_IDADE_N,N,4,0  3050 non-null   int64
#  14  CS_SEXO,C,1       3050 non-null   object
#  15  CS_GESTANT,C,1    3050 non-null   int64
# ...

# %% [markdown]
# **TRATANDO ALGUMAS INFORMAÇÕES NAS COLUNAS:**
#
# Algumas infomrações estão com encodificações, então visando facilitar abordagens e o entendimento, estou "traduzindo" alguns valores

# %%
df.isnull().sum()
# Out:
# NU_NOTIFIC,C,7        0
# TP_NOT,C,1            0
# ID_AGRAVO,C,5         0
# DT_NOTIFIC,D          0
# SEM_NOT,C,6           0
#                    ...
# DS_OBS,C,255       3032
# TP_SISTEMA,C,1      105
# DT_DIGITA,D           1
# CS_FLXRET,C,1         0
# IDENT_MICR,C,50     129
# Length: 86, dtype: int64

# %%
#Corrigindo as codificações de raça

df['CS_RACA,C,1'] = df['CS_RACA,C,1'].replace({
    1: 'BRANCO',
    2: 'PRETO',
    3: 'AMARELO',
    4: 'PARDO',
    5: 'INDIGENA',
    9: 'IGNORADO'
})

# %%
#Organizando a coluna de gêneros

generos={
    'M': 'HOMEM',
    'F': 'MULHER'
}
df['CS_SEXO,C,1']=df['CS_SEXO,C,1'].replace(generos)

# %%
#Tratando codificação de zonas

zonas={
    1: 'URBANA',
    2: 'RURAL',
    3: 'PERIURBANA',
    9: 'IGNORADO'
}
df['CS_ZONA,C,1']=df['CS_ZONA,C,1'].replace(zonas)

# %%
#Tratando codificação de sorotipos circulantes

sorotipos={
    1:'DENV 1',
    2: 'DENV 2',
    3: 'DENV 3',
    4: 'DENV 4'
}
df['SOROTIPO,C,1']=df['SOROTIPO,C,1'].replace(sorotipos)

# %% [markdown]
# **-----------------------------FIM DO TRATAMENTO DE COLUNAS--------------------------**

# %%
np.unique(df['CS_SEXO,C,1'].astype(str), return_counts= True)
# Out:
# (array(['HOMEM', 'MULHER'], dtype=object), array([1382, 1668]))

# %%
df['DT_NOTIFIC,D'] = pd.to_datetime(df['DT_NOTIFIC,D'], format='%m/%d/%y')
df['MES DO CASO'] = df['DT_NOTIFIC,D'].dt.month

# %%
#Organizando os meses de incidencia

meses = {
    1: 'Janeiro',
    2: 'Fevereiro',
    3: 'Março',
    4: 'Abril',
    5: 'Maio',
    6: 'Junho',
    7: 'Julho',
    8: 'Agosto',
    9: 'Setembro',
    10: 'Outubro',
    11: 'Novembro',
    12: 'Dezembro'
}
df['MES DO CASO'] = df['MES DO CASO'].replace(meses)

# %%
df
# Out:
#       NU_NOTIFIC,C,7  TP_NOT,C,1 ID_AGRAVO,C,5 DT_NOTIFIC,D  SEM_NOT,C,6  \
# 0            6902153           2           A90   2025-02-21       202508
# 1              93151           2           A90   2025-09-14       202538
# 2              93227           2           A90   2025-09-23       202539
# 3              93254           2           A90   2025-09-11       202537
# 4              93193           2           A90   2025-09-26       202539
# ...              ...         ...           ...          ...          ...
# 3045         7040821           2           A90   2025-03-27       202513
# 3046         5917940           2           A90   2025-01-28       202505
# 3047         5703527           2           A90   2025-05-16       202520
# 3048          902713           2           A90   2025-04-16       202516
# 3049         5003111           2           A90   2025-07-25       202530
#
#       NU_ANO,C,4  SG_UF_NOT,C,2  ID_MUNICIP,C,6  ID_REGIONA,C,8  \
# ...

# %%
np.unique(df['ID_MN_RESI,C,6'])
# Out:
# array([250400])

# %%
np.unique(df['MES DO CASO'].astype(str), return_counts=True)
# Out:
# (array(['Abril', 'Agosto', 'Fevereiro', 'Janeiro', 'Julho', 'Junho',
#         'Maio', 'Março', 'Novembro', 'Outubro', 'Setembro'], dtype=object),
#  array([283, 233, 537, 217, 173, 240, 296, 396, 131, 240, 304]))

# %%
np.unique(df['NM_BAIRRO,C,60'].astype(str), return_counts=True)
# Out:
# (array(['ACACIO FIGUEIREDO', 'ACUDE DE DENTRO', 'ALTO BRANCO',
#         'ALUISIO CAMPOS', 'ALUIZIO CAMPOS', 'ARAXA', 'BAIRRO - GALETO',
#         'BAIRRO DAS CIDADES', 'BAIRRO DAS NACOES', 'BAIRRO UNIVERSITARIO',
#         'BELA VISTA', 'BODOCONGO', 'BOSQUE', 'CAJAZEIRAS', 'CAPIM GRANDE',
#         'CARDOSO DE BAIXO', 'CASTELO BRANCO', 'CATOLE',
#         'CATOLE DE BOA VISTA', 'CATOLE DE JOSE FERREIRA',
#         'CATOLE ZE FERREIRA', 'CENTENARIO', 'CENTRO', 'CINZA', 'CONCEICAO',
#         'CONJ SEVERINO CABRAL', 'CRUZEIRO', 'CUITES', 'DINAMERICA',
#         'DISTRITO INDUSTRIAL', 'ESTACAO VELHA', 'ESTREITO', 'FELIX AMARO',
#         'GALANTE', 'GLORIA', 'ITARARE', 'JARDIM CONTINENTAL',
#         'JARDIM PAULISTANO', 'JARDIM QUARENTA', 'JARDIM TAVARES',
#         'JARDIM VERDEJANTE', 'JEREMIAS', 'JORGE', 'JOSE PINHEIRO',
#         'LAGOA DE DENTRO', 'LARANJEIRAS', 'LAURITZEN', 'LIBERDADE',
#         'LIGEIRO', 'LOUZEIRO', 'LUCAS', 'MALVINAS', 'MALVINAS I',
# ...

# %%
#Corrigindo incoerências na coluna de bairros


df['NM_BAIRRO,C,60']=df['NM_BAIRRO,C,60'].replace({
    'VELHA' : 'ESTACAO VELHA',
    'MALVINAS I': 'MALVINAS',
    'TRES IRMAES': 'TRES IRMAS',
    'BOSQUE': 'SAO JOSE DA MATA',
    'PRESIDENTE MEDICE': 'PRESIDENTE MEDICI',
    'QUARENTA': 'JARDIM QUARENTA',
    'MALVINAS I': 'MALVINAS',
    'SÒO JOSE': 'SAO JOSE',
    'ALUISIO CAMPOS': 'ALUIZIO CAMPOS',
    'BAIRRO - GALETO': 'CATOLE',
    'CAPIM GRANDE': 'SITIO CAPIM GRANDE',
    'CATOLE DE JOSE FERREIRA': 'CATOLE DE ZE FERREIRA',
    'CATOLE ZE FERREIRA': 'CATOLE DE ZE FERREIRA',
    'FELIX AMARO': 'SITIO FELIX AMARO',
    'JORGE': 'SITIO JORGE',
    'RAMADINHA II': 'RAMADINHA',
    'SITI': 'SITIO BOI VELHA',
    'LUCAS': 'SITIO LUCAS'

})

# %%
#Arrumando os graus de escolaridade

escolaridade={
    0: 'ANALFABETO',
    1: 'PRIMARIO INCOMPLETO',
    2: 'PRIMARIO COMPLETO',
    3: '1 GRAU INCOMPLETO',
    4: 'FUNDAMENTAL COMPLETO',
    5: 'ENSINO MÉDIO INCOMPLETO',
    6: 'ENSINO MÉDIO COMPLETO',
    7: 'SUPERIOR INCOMPLETO',
    8: 'SUPERIOR COMPLETO',
    9: 'IGNORADO',
    10: 'NÃO SE APLICA'
}
df['CS_ESCOL_N,C,2']=df['CS_ESCOL_N,C,2'].replace(escolaridade)

# %%
df['NM_BAIRRO,C,60'] = df['NM_BAIRRO,C,60'].str.strip()


bairros_limpos, freq_limpa = np.unique(df['NM_BAIRRO,C,60'].astype(str), return_counts=True)
display(pd.DataFrame({'NM_BAIRRO,C,60': bairros_limpos, 'Count': freq_limpa}).sort_values(by='Count', ascending=False).head(20))
# Out:
#        NM_BAIRRO,C,60  Count
# 43           MALVINAS    271
# 83         TRES IRMAS    258
# 9           BODOCONGO    161
# 69         SANTA ROSA    119
# 76           SERROTAO    114
# 21           CRUZEIRO    112
# 13             CATOLE     97
# 40          LIBERDADE     95
# 32    JARDIM QUARENTA     83
# 61          RAMADINHA     79
# 68         SANTA CRUZ     70
# 59  PRESIDENTE MEDICI     70
# 85             VELAME     68
# 17             CENTRO     67
# 3      ALUIZIO CAMPOS     66
# 0   ACACIO FIGUEIREDO     66
# 55           PEDREGAL     65
# 36      JOSE PINHEIRO     59
# 16         CENTENARIO     56
# 48        MONTE SANTO     56

# %%
# Calculate the frequency of each neighborhood
neighborhood_frequency = df['NM_BAIRRO,C,60'].value_counts().reset_index()
neighborhood_frequency.columns = ['Bairro', 'Frequência']

# Sort the DataFrame by frequency in descending order
neighborhood_frequency = neighborhood_frequency.sort_values(by='Frequência', ascending=False)

# Get the top N neighborhoods for better visualization (optional, adjust N as needed)
# For now, let's display all, but if there are too many, we might limit it.
# neighborhood_frequency_top = neighborhood_frequency.head(20)

# Create the bar chart
fig = plx.bar(
    neighborhood_frequency,
    x='Bairro',
    y='Frequência',
    title='Frequência de Casos por Bairro',
    labels={'Bairro': 'Bairro', 'Frequência': 'Número de Casos'},
    color_discrete_sequence=plx.colors.qualitative.Pastel
)

fig.update_layout(
    xaxis_title='Bairro',
    yaxis_title='Número de Casos',
    xaxis_tickangle=-45 # Rotate x-axis labels for better readability
)

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
#Trazendo as estações para trabalhar abordagens

estacoes_por_mes={
    'Dezembro' : 'VERAO',
    'Janeiro': 'VERAO',
    'Fevereiro': 'VERAO',
    'Março': 'VERAO',
    'Abril': 'OUTONO',
    'Maio': 'OUTONO',
    'Junho': 'OUTONO',
    'Julho': 'INVERNO',
    'Agosto': 'INVERNO',
    'Setembro': 'INVERNO',
    'Outubro': 'PRIMAVERA',
    'Novembro': 'PRIMAVERA'
}
df['ESTACAO POR CASO']=df['MES DO CASO'].replace(estacoes_por_mes)

# %%
df['ESTACAO POR CASO'].value_counts()
# Out:
# ESTACAO POR CASO
# VERAO        1150
# OUTONO        819
# INVERNO       710
# PRIMAVERA     371
# Name: count, dtype: int64

# %%
df['CS_ZONA,C,1'].value_counts()
# Out:
# CS_ZONA,C,1
# URBANA    2966
# RURAL       54
# Name: count, dtype: int64

# %%
df['CS_RACA,C,1'].value_counts()
# Out:
# CS_RACA,C,1
# PARDO       3003
# AMARELO       14
# IGNORADO      14
# BRANCO        10
# INDIGENA       8
# PRETO          1
# Name: count, dtype: int64

# %%
df['SOROTIPO,C,1'].astype(str).value_counts()
# Out:
# SOROTIPO,C,1
# nan       2954
# DENV 2      58
# DENV 1      33
# DENV 3       5
# Name: count, dtype: int64

# %%
df.rename(columns={
    'DT_NOTIFIC,D': 'DATA REGISTRO',
    'CS_SEXO,C,1': 'SEXO DO PACIENTE',
    'CS_RACA,C,1': 'RAÇA',
    'CS_ESCOL_N,C,2': 'GRAU ESCOLARIDADE',
    'NM_BAIRRO,C,60': 'BAIRRO',
    'CS_ZONA,C,1': 'ZONA',
    'ID_UNIDADE,C,7': 'UNIDADE DE ATENDIMENTO',
    'DT_NASC,D': 'DATA DE NASCIMENTO',
    'CLASSI_FIN,C,2': 'CLASS DOENCA',
    'SEM_PRI,C,6': 'SEMANA EPDM',
    'DT_SIN_PRI,D': 'DATA PRIMEIROS SINTOMAS',
    'SOROTIPO,C,1': 'SOROTIPO'

},inplace=True)

# %%
df['GRAU ESCOLARIDADE'].astype(str).value_counts()
# Out:
# GRAU ESCOLARIDADE
# ENSINO MÉDIO COMPLETO      2810
# NÃO SE APLICA                53
# ENSINO MÉDIO INCOMPLETO      50
# IGNORADO                     35
# 1 GRAU INCOMPLETO            22
# PRIMARIO COMPLETO            21
# nan                          20
# FUNDAMENTAL COMPLETO         19
# PRIMARIO INCOMPLETO           9
# SUPERIOR INCOMPLETO           7
# SUPERIOR COMPLETO             4
# Name: count, dtype: int64

# %%
df['DATA DE NASCIMENTO'] = pd.to_datetime(df['DATA DE NASCIMENTO'], format='%m/%d/%y', errors='coerce')

# Correcting years that are in the future (e.g., '25' interpreted as 2025 instead of 1925)
def adjust_year(date_series):
    current_year = pd.Timestamp.now().year
    adjusted_dates = []
    for date in date_series:
        if pd.isna(date):
            adjusted_dates.append(pd.NaT)
            continue
        if date.year > current_year:
            adjusted_dates.append(date - pd.DateOffset(years=100))
        else:
            adjusted_dates.append(date)
    return pd.Series(adjusted_dates, index=date_series.index)

df['DATA DE NASCIMENTO'] = adjust_year(df['DATA DE NASCIMENTO'])

# Calculate age in years
df['IDADE EM ANOS'] = (df['DATA REGISTRO'] - df['DATA DE NASCIMENTO']).dt.days / 365.25

# Round the age to the nearest integer
df['IDADE EM ANOS'] = df['IDADE EM ANOS'].round().astype('Int64')

display(df[['DATA DE NASCIMENTO', 'DATA REGISTRO', 'IDADE EM ANOS']].head())
# Out:
#   DATA DE NASCIMENTO DATA REGISTRO  IDADE EM ANOS
# 0         1985-06-05    2025-02-21             40
# 1         1981-09-15    2025-09-14             44
# 2         1993-12-08    2025-09-23             32
# 3         2005-07-26    2025-09-11             20
# 4         1999-05-01    2025-09-26             26

# %%
df['IDADE EM ANOS'].value_counts()
# Out:
# IDADE EM ANOS
# 23    144
# 25    128
# 26    122
# 24    115
# 22    110
#      ...
# 87      1
# 98      1
# 94      1
# 88      1
# 90      1
# Name: count, Length: 92, dtype: Int64

# %%
df_final2025 = df[['IDADE EM ANOS', 'SEXO DO PACIENTE','RAÇA','ESTACAO POR CASO','MES DO CASO','GRAU ESCOLARIDADE','BAIRRO','ZONA','UNIDADE DE ATENDIMENTO','DATA REGISTRO', 'CLASS DOENCA','SEMANA EPDM', 'DATA PRIMEIROS SINTOMAS','SOROTIPO']]

# %%
df_final2025.head()
# Out:
#    IDADE EM ANOS SEXO DO PACIENTE   RAÇA ESTACAO POR CASO MES DO CASO  \
# 0             40            HOMEM  PARDO            VERAO   Fevereiro
# 1             44            HOMEM  PARDO          INVERNO    Setembro
# 2             32           MULHER  PARDO          INVERNO    Setembro
# 3             20           MULHER  PARDO          INVERNO    Setembro
# 4             26            HOMEM  PARDO          INVERNO    Setembro
#
#        GRAU ESCOLARIDADE       BAIRRO    ZONA  UNIDADE DE ATENDIMENTO  \
# 0               IGNORADO   TRES IRMAS     NaN                 2639548
# 1  ENSINO MÉDIO COMPLETO     MALVINAS  URBANA                 9374833
# 2  ENSINO MÉDIO COMPLETO    BODOCONGO  URBANA                 9374833
# 3  ENSINO MÉDIO COMPLETO   TRES IRMAS  URBANA                 9352902
# 4  ENSINO MÉDIO COMPLETO  ALTO BRANCO  URBANA                 7052251
#
#   DATA REGISTRO CLASS DOENCA  SEMANA EPDM DATA PRIMEIROS SINTOMAS SOROTIPO
# ...

# %%
df_final2025 = df_final2025[df_final2025['CLASS DOENCA'] != 'DESCARTADO']
df_final2025 = df_final2025[df_final2025['CLASS DOENCA'] != 'CHIKUNGUNYA']

# Map the unclassified '8.0' to 'DENGUE'
df_final2025['CLASS DOENCA'] = df_final2025['CLASS DOENCA'].replace({8.0: 'DENGUE'})

# The previous fillna(None) was causing an error. NaN values will remain as NaN in object dtype columns.

display(df_final2025.head())
# Out:
#     IDADE EM ANOS SEXO DO PACIENTE   RAÇA ESTACAO POR CASO MES DO CASO  \
# 0              40            HOMEM  PARDO            VERAO   Fevereiro
# 32             22            HOMEM  PARDO            VERAO     Janeiro
# 35             47           MULHER  PARDO            VERAO     Janeiro
# 87             23           MULHER  PARDO            VERAO     Janeiro
# 89             26            HOMEM  PARDO           OUTONO       Abril
#
#         GRAU ESCOLARIDADE           BAIRRO    ZONA  UNIDADE DE ATENDIMENTO  \
# 0                IGNORADO       TRES IRMAS     NaN                 2639548
# 32  ENSINO MÉDIO COMPLETO          GALANTE  URBANA                 9374833
# 35  ENSINO MÉDIO COMPLETO       DINAMERICA  URBANA                 2363275
# 87  ENSINO MÉDIO COMPLETO  JARDIM QUARENTA     NaN                 3006204
# 89  ENSINO MÉDIO COMPLETO        BODOCONGO  URBANA                 7052251
#
#    DATA REGISTRO CLASS DOENCA  SEMANA EPDM DATA PRIMEIROS SINTOMAS SOROTIPO
# ...

# %%
np.unique(df_final2025['ZONA'].astype(str),return_counts=True)
# Out:
# (array(['RURAL', 'URBANA', 'nan'], dtype=object), array([  6, 206,   8]))

# %%
# 1. Dicionário Exclusivo (Baseado na sua lista fornecida)
unidades = {
    # --- Grandes Hospitais / Maternidades ---
    220337: "HOSPITAL DE CLINICAS DE CAMPINA GRANDE",
    2362287: "INSTITUTO DE SAUDE ELPIDIO DE ALMEIDA ISEA",
    2362848: "HOSPITAL DA FAP",
    2362856: "HOSPITAL DE EMERGENCIA E TRAUMA DOM LUIZ GONZAGA FERNANDES",
    2362880: "HOSPITAL MUNICIPAL DR EDGLEY",
    2363070: "HOSPITAL MUNICIPAL PEDRO I",
    2676060: "HOSPITAL UNIVERSITARIO ALCIDES CARNEIRO (HUAC)",
    7113692: "HOSPITAL MUNICIPAL DR SEVERINO BEZERRA DE CARVALHO",

    # --- UPAs (Unidades de Pronto Atendimento) ---
    3056724: "UPA 24H DR MAIA (ALTO BRANCO) - ANTIGO",
    7052251: "UPA 24H DR MAIA (ALTO BRANCO)",
    5480957: "UPA 24H DR ADHEMAR DANTAS (DINAMERICA) - ANTIGO",
    9374833: "UPA 24H DR ADHEMAR DANTAS (DINAMERICA)",

    # --- Clínicas Especializadas / Centros de Referência ---
    2362627: "CLIPE CLINICA PEDIATRICA",
    2362678: "UROCLINICA",
    2362732: "CENTRO MEDICO SANTA CLARA",
    2362767: "CLINICA E MATERNIDADE DR LUIZ G MOURA",
    2362821: "INSTITUTO SAO VICENTE DE PAULO",
    2362953: "APAE",
    2363275: "VIGILANCIA EPIDEMIOLOGICA",
    2415631: "HEMOCENTRO REGIONAL DE CAMPINA GRANDE",
    2639548: "CEO II CENTRO DE ESPECIALIDADES ODONTOLOGICAS",
    2806045: "CAPS AD III",
    2975637: "LABORATORIO DE ANALISES CLINICAS DO MUNICIPIO",
    3006204: "CLINICA SANTA CLARA",
    4313593: "CEREST REGIONAL",
    5116279: "SAMU 192",
    6267939: "POLICLINICA DO CATOLE",
    6985483: "CAPS I",
    9145133: "ACADEMIA DE SAUDE",

    # --- Centros de Saúde e UBS (Atenção Básica) ---
    2336960: "CENTRO DE SAUDE DA PALMEIRA",
    2362260: "CENTRO DE SAUDE DE SAO JOSE DA MATA",
    2362279: "CENTRO DE SAUDE DA LIBERDADE",
    2362309: "CENTRO DE SAUDE DE SANTA ROSA",
    2362317: "CENTRO DE SAUDE FRANCISCO PINTO",
    2362325: "CENTRO DE SAUDE DO CATOLE",
    2362392: "UNIDADE MISTA DE GALANTE",
    2362406: "CENTRO DE SAUDE DE BODOCONGO",
    2595397: "UBS RAIMUNDO CARNEIRO",
    2595400: "UBS BENJAMIN B MARANHAO",
    2595451: "UBS MALVINAS IV",
    2677725: "UBS CIDADES",
    2792788: "UBS MARIA DE LOURDES LEONCIO",
    2792877: "UBS PARQUE DOS SERIDO",
    5053129: "UBS GALANTE I",
    5053269: "UBS SAO JOSE DA MATA I",
    5116457: "UBS ODETE LEANDRO",
    5131960: "UBS BAIRRO DAS CIDADES",
    5485754: "UBS RESIDENCIAL MAJOR VENEZIANO",
    5491215: "UBS PORTAL SUDOESTE",
    5616212: "UBS ALOISIO PEREIRA LIMA",
    5932416: "UBS NOVO CRUZEIRO",
    5968992: "UBS ANA CANTALICE",
    6045340: "UBS JOSEFA VENTURA TOME",
    6679528: "UBS ACACIO FIGUEIREDO",
    7417659: "UBS COLINAS DO SOL",
    7870930: "UBS JARDIM VERDEJANTE",
    9263691: "UBS GRANDE CAMPINA",
    9352899: "UBS RAMADINHA II",
    9352902: "UBS BAIRRO DAS NACOES",
    9385924: "UBS NOVA BRASILIA",
    9387927: "UBS VILA NOVA",

    # --- Erros / Outros ---
    1120: "CODIGO INVALIDO (ERRO DE REGISTRO)"
}

# 2. Lista de IDs considerados de Campina Grande (Todos exceto o 1120)
ids_campina_grande = [
    220337, 2336960, 2362260, 2362279, 2362287, 2362309, 2362317, 2362325,
    2362392, 2362406, 2362627, 2362678, 2362732, 2362767, 2362821, 2362848,
    2362856, 2362880, 2362953, 2363070, 2363275, 2415631, 2595397, 2595400,
    2595451, 2639548, 2676060, 2677725, 2792788, 2792877, 2806045, 2975637,
    3006204, 3056724, 4313593, 5053129, 5053269, 5116279, 5116457, 5131960,
    5480957, 5485754, 5491215, 5616212, 5932416, 5968992, 6045340, 6267939,
    6679528, 6985483, 7052251, 7113692, 7417659, 7870930, 9145133, 9263691,
    9352899, 9352902, 9374833, 9385924, 9387927
]

# --- APLICAÇÃO NO DATAFRAME ---

# 1. Converter para numérico para garantir que o 'join' funcione com o dicionário
df_final2025['UNIDADE DE ATENDIMENTO'] = pd.to_numeric(df_final2025['UNIDADE DE ATENDIMENTO'], errors='coerce')

# 2. Criar a classificação de Origem (Campina Grande vs Outros/Erro)
df_final2025['ORIGEM_UNIDADE'] = np.where(
    df_final2025['UNIDADE DE ATENDIMENTO'].isin(ids_campina_grande),
    'Campina Grande',
    'Externo/Outro/Erro'
)

# 3. Substituir os códigos pelos nomes das unidades
df_final2025['UNIDADE DE ATENDIMENTO'] = df_final2025['UNIDADE DE ATENDIMENTO'].replace(unidades)

# %%
df_final2025
# Out:
#       IDADE EM ANOS SEXO DO PACIENTE      RAÇA ESTACAO POR CASO MES DO CASO  \
# 0                40            HOMEM     PARDO            VERAO   Fevereiro
# 32               22            HOMEM     PARDO            VERAO     Janeiro
# 35               47           MULHER     PARDO            VERAO     Janeiro
# 87               23           MULHER     PARDO            VERAO     Janeiro
# 89               26            HOMEM     PARDO           OUTONO       Abril
# ...             ...              ...       ...              ...         ...
# 3044             55           MULHER  IGNORADO          INVERNO      Agosto
# 3045             24           MULHER    BRANCO            VERAO       Março
# 3046             25            HOMEM  IGNORADO            VERAO     Janeiro
# 3047             51            HOMEM     PARDO           OUTONO        Maio
# 3049             30           MULHER     PARDO          INVERNO       Julho
#
#           GRAU ESCOLARIDADE           BAIRRO    ZONA  \
# ...

# %%
df_final2025['RAÇA'].replace('IGNORADO','PARDO',inplace=True)
# Out:
# /tmp/ipython-input-722296122.py:1: FutureWarning:
#
# A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.

# %%
# Fill NaN values in the 'ZONA' column with 'URBANA'
df_final2025['ZONA'].fillna('URBANA', inplace=True)

# Display unique values and their counts for 'ZONA' to confirm the change
np.unique(df_final2025['ZONA'].astype(str), return_counts=True)
# Out:
# /tmp/ipython-input-1317722477.py:2: FutureWarning:
#
# A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
# (array(['RURAL', 'URBANA'], dtype=object), array([  6, 214]))

# %%
np.unique(df_final2025['UNIDADE DE ATENDIMENTO'].astype(str),return_counts=True)
# Out:
# (array(['ACADEMIA DE SAUDE', 'APAE', 'CAPS AD III', 'CAPS I',
#         'CENTRO DE SAUDE DA PALMEIRA',
#         'CEO II CENTRO DE ESPECIALIDADES ODONTOLOGICAS', 'CEREST REGIONAL',
#         'CLINICA SANTA CLARA', 'CODIGO INVALIDO (ERRO DE REGISTRO)',
#         'HEMOCENTRO REGIONAL DE CAMPINA GRANDE',
#         'HOSPITAL DE CLINICAS DE CAMPINA GRANDE',
#         'HOSPITAL DE EMERGENCIA E TRAUMA DOM LUIZ GONZAGA FERNANDES',
#         'HOSPITAL MUNICIPAL DR EDGLEY',
#         'HOSPITAL MUNICIPAL DR SEVERINO BEZERRA DE CARVALHO',
#         'HOSPITAL MUNICIPAL PEDRO I',
#         'HOSPITAL UNIVERSITARIO ALCIDES CARNEIRO (HUAC)',
#         'INSTITUTO DE SAUDE ELPIDIO DE ALMEIDA ISEA',
#         'INSTITUTO SAO VICENTE DE PAULO', 'UBS ALOISIO PEREIRA LIMA',
#         'UBS COLINAS DO SOL', 'UBS GRANDE CAMPINA', 'UBS VILA NOVA',
#         'UPA 24H DR ADHEMAR DANTAS (DINAMERICA)',
#         'UPA 24H DR MAIA (ALTO BRANCO)',
#         'UPA 24H DR MAIA (ALTO BRANCO) - ANTIGO',
# ...

# %%
df_final2025['UNIDADE DE ATENDIMENTO'].value_counts()
# Out:
# UNIDADE DE ATENDIMENTO
# UPA 24H DR ADHEMAR DANTAS (DINAMERICA)                        62
# HOSPITAL MUNICIPAL PEDRO I                                    52
# UPA 24H DR MAIA (ALTO BRANCO)                                 22
# HOSPITAL MUNICIPAL DR EDGLEY                                  16
# HOSPITAL MUNICIPAL DR SEVERINO BEZERRA DE CARVALHO            10
# VIGILANCIA EPIDEMIOLOGICA                                     10
# CLINICA SANTA CLARA                                            8
# HOSPITAL DE EMERGENCIA E TRAUMA DOM LUIZ GONZAGA FERNANDES     5
# INSTITUTO DE SAUDE ELPIDIO DE ALMEIDA ISEA                     5
# HOSPITAL UNIVERSITARIO ALCIDES CARNEIRO (HUAC)                 5
# ACADEMIA DE SAUDE                                              5
# UBS ALOISIO PEREIRA LIMA                                       3
# CODIGO INVALIDO (ERRO DE REGISTRO)                             2
# HOSPITAL DE CLINICAS DE CAMPINA GRANDE                         2
# ...

# %%
unidades_s, freq_limpa = np.unique(df_final2025['UNIDADE DE ATENDIMENTO'].astype(str), return_counts=True)
display(pd.DataFrame({'UNIDADE DE ATENDIMENTO': unidades_s, 'Count': freq_limpa}).sort_values(by='Count', ascending=False).head(20))
# Out:
#                                UNIDADE DE ATENDIMENTO  Count
# 22             UPA 24H DR ADHEMAR DANTAS (DINAMERICA)     62
# 14                         HOSPITAL MUNICIPAL PEDRO I     52
# 23                      UPA 24H DR MAIA (ALTO BRANCO)     22
# 12                       HOSPITAL MUNICIPAL DR EDGLEY     16
# 25                          VIGILANCIA EPIDEMIOLOGICA     10
# 13  HOSPITAL MUNICIPAL DR SEVERINO BEZERRA DE CARV...     10
# 7                                 CLINICA SANTA CLARA      8
# 16         INSTITUTO DE SAUDE ELPIDIO DE ALMEIDA ISEA      5
# 11  HOSPITAL DE EMERGENCIA E TRAUMA DOM LUIZ GONZA...      5
# 0                                   ACADEMIA DE SAUDE      5
# 15     HOSPITAL UNIVERSITARIO ALCIDES CARNEIRO (HUAC)      5
# 18                           UBS ALOISIO PEREIRA LIMA      3
# 10             HOSPITAL DE CLINICAS DE CAMPINA GRANDE      2
# 1                                                APAE      2
# ...

# %%
df_final2025['SEXO DO PACIENTE'].astype(str).value_counts()
# Out:
# SEXO DO PACIENTE
# MULHER    125
# HOMEM      95
# Name: count, dtype: int64

# %%
df_final2025['DATA REGISTRO'] = df_final2025['DATA REGISTRO'].dt.year
display(df_final2025.head())
# Out:
#     IDADE EM ANOS SEXO DO PACIENTE   RAÇA ESTACAO POR CASO MES DO CASO  \
# 0              40            HOMEM  PARDO            VERAO   Fevereiro
# 32             22            HOMEM  PARDO            VERAO     Janeiro
# 35             47           MULHER  PARDO            VERAO     Janeiro
# 87             23           MULHER  PARDO            VERAO     Janeiro
# 89             26            HOMEM  PARDO           OUTONO       Abril
#
#         GRAU ESCOLARIDADE           BAIRRO    ZONA  \
# 0                IGNORADO       TRES IRMAS  URBANA
# 32  ENSINO MÉDIO COMPLETO          GALANTE  URBANA
# 35  ENSINO MÉDIO COMPLETO       DINAMERICA  URBANA
# 87  ENSINO MÉDIO COMPLETO  JARDIM QUARENTA  URBANA
# 89  ENSINO MÉDIO COMPLETO        BODOCONGO  URBANA
#
#                            UNIDADE DE ATENDIMENTO  DATA REGISTRO CLASS DOENCA  \
# 0   CEO II CENTRO DE ESPECIALIDADES ODONTOLOGICAS           2025       DENGUE
# ...

# %%
df_final2025['SEMANA EPDM'] = df_final2025['SEMANA EPDM'].astype(str).str[-2:]
display(df_final2025.head())
# Out:
#     IDADE EM ANOS SEXO DO PACIENTE   RAÇA ESTACAO POR CASO MES DO CASO  \
# 0              40            HOMEM  PARDO            VERAO   Fevereiro
# 32             22            HOMEM  PARDO            VERAO     Janeiro
# 35             47           MULHER  PARDO            VERAO     Janeiro
# 87             23           MULHER  PARDO            VERAO     Janeiro
# 89             26            HOMEM  PARDO           OUTONO       Abril
#
#         GRAU ESCOLARIDADE           BAIRRO    ZONA  \
# 0                IGNORADO       TRES IRMAS  URBANA
# 32  ENSINO MÉDIO COMPLETO          GALANTE  URBANA
# 35  ENSINO MÉDIO COMPLETO       DINAMERICA  URBANA
# 87  ENSINO MÉDIO COMPLETO  JARDIM QUARENTA  URBANA
# 89  ENSINO MÉDIO COMPLETO        BODOCONGO  URBANA
#
#                            UNIDADE DE ATENDIMENTO  DATA REGISTRO CLASS DOENCA  \
# 0   CEO II CENTRO DE ESPECIALIDADES ODONTOLOGICAS           2025       DENGUE
# ...

# %%
df_final2025['GRAU ESCOLARIDADE'].replace('IGNORADO','ENSINO MÉDIO COMPLETO',inplace=True)
df_final2025['GRAU ESCOLARIDADE'].value_counts()
# Out:
# /tmp/ipython-input-1775076814.py:1: FutureWarning:
#
# A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
# GRAU ESCOLARIDADE
# ENSINO MÉDIO COMPLETO      188
# ENSINO MÉDIO INCOMPLETO      7
# 1 GRAU INCOMPLETO            5
# NÃO SE APLICA                5
# PRIMARIO INCOMPLETO          3
# FUNDAMENTAL COMPLETO         1
# SUPERIOR INCOMPLETO          1
# PRIMARIO COMPLETO            1
# SUPERIOR COMPLETO            1
# Name: count, dtype: int64

# %%
np.unique(df_final2025['BAIRRO'].astype(str))
# Out:
# array(['ACACIO FIGUEIREDO', 'ALTO BRANCO', 'ALUIZIO CAMPOS', 'ARAXA',
#        'BAIRRO DAS CIDADES', 'BAIRRO DAS NACOES', 'BAIRRO UNIVERSITARIO',
#        'BELA VISTA', 'BODOCONGO', 'CATOLE', 'CATOLE DE ZE FERREIRA',
#        'CENTENARIO', 'CENTRO', 'CRUZEIRO', 'DINAMERICA', 'ESTACAO VELHA',
#        'GALANTE', 'ITARARE', 'JARDIM PAULISTANO', 'JARDIM QUARENTA',
#        'JARDIM TAVARES', 'JEREMIAS', 'JOSE PINHEIRO', 'LAGOA DE DENTRO',
#        'LIBERDADE', 'LIGEIRO', 'LOUZEIRO', 'MALVINAS', 'MARINHO',
#        'MIRANTE', 'MONTE SANTO', 'NOVA BRASILIA', 'NOVO HORIZONTE',
#        'PALMEIRA', 'PALMEIRA IMPERIAL', 'PEDREGAL', 'PRESIDENTE MEDICI',
#        'RAMADINHA', 'ROCHA CAVALCANTE', 'SANDRA CAVALCANTE', 'SANTA CRUZ',
#        'SANTA ROSA', 'SANTO ANTONIO', 'SAO JOSE', 'SAO JOSE DA MATA',
#        'SERRA DE JOAQUIM VIEIRA', 'SERROTAO', 'SITIO BOI VELHA',
#        'SITIO LUCAS', 'TAMBOR', 'TRES IRMAS', 'UNIVERSITARIO', 'VELAME',
# ...

# %%
df_final2025['BAIRRO']=df_final2025['BAIRRO'].replace({
    'BAIRRO - GALETO': 'CATOLE',
    'LUCAS': 'SITIO LUACAS',
    'PALMEIRA IMPERIAL': 'PALMEIRA',
    'URBANA': 'JARDIM QUARENTA',
    'ZONA RURAL': 'JARDIM QUARENTA',
    'RAMADINHA II': 'RAMADINHA',
    'BAIRRO DAS NACOES': 'NACOES',
    'CATOLE DE JOSE FERREIRA': 'CATOLE DE ZE FERREIRA',
    'PRESIDENTE MEDICI': 'PRESIDENTE MEDICE',
    'UNIVERSITARIO': 'BAIRRO UNIVERSITARIO',
    'SITIO BOI VELHA': 'SITIO BOI VELHO'
})

# %%
# Calculate the frequency of each neighborhood
neighborhood_frequency = df_final2025['BAIRRO'].value_counts().reset_index()
neighborhood_frequency.columns = ['Bairro', 'Frequência']

# Sort the DataFrame by frequency in descending order
neighborhood_frequency = neighborhood_frequency.sort_values(by='Frequência', ascending=False)

# Get the top N neighborhoods for better visualization (optional, adjust N as needed)
# For now, let's display all, but if there are too many, we might limit it.
# neighborhood_frequency_top = neighborhood_frequency.head(20)

# Create the bar chart
fig = plx.bar(
    neighborhood_frequency,
    x='Bairro',
    y='Frequência',
    title='Frequência de Casos por Bairro',
    labels={'Bairro': 'Bairro', 'Frequência': 'Número de Casos'},
    color_discrete_sequence=plx.colors.qualitative.Pastel
)

fig.update_layout(
    xaxis_title='Bairro',
    yaxis_title='Número de Casos',
    xaxis_tickangle=-45 # Rotate x-axis labels for better readability
)

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
df_final2025['CLASS DOENCA'].value_counts()
# Out:
# CLASS DOENCA
# DENGUE    213
# Name: count, dtype: int64

# %%
df_final2025['SOROTIPO'].value_counts()
# Out:
# SOROTIPO
# DENV 2    56
# DENV 1    28
# DENV 3     5
# Name: count, dtype: int64

# %%
np.unique(df_final2025['BAIRRO'].astype(str),return_counts=True)
# Out:
# (array(['ACACIO FIGUEIREDO', 'ALTO BRANCO', 'ALUIZIO CAMPOS', 'ARAXA',
#         'BAIRRO DAS CIDADES', 'BAIRRO UNIVERSITARIO', 'BELA VISTA',
#         'BODOCONGO', 'CATOLE', 'CATOLE DE ZE FERREIRA', 'CENTENARIO',
#         'CENTRO', 'CRUZEIRO', 'DINAMERICA', 'ESTACAO VELHA', 'GALANTE',
#         'ITARARE', 'JARDIM PAULISTANO', 'JARDIM QUARENTA',
#         'JARDIM TAVARES', 'JEREMIAS', 'JOSE PINHEIRO', 'LAGOA DE DENTRO',
#         'LIBERDADE', 'LIGEIRO', 'LOUZEIRO', 'MALVINAS', 'MARINHO',
#         'MIRANTE', 'MONTE SANTO', 'NACOES', 'NOVA BRASILIA',
#         'NOVO HORIZONTE', 'PALMEIRA', 'PEDREGAL', 'PRESIDENTE MEDICE',
#         'RAMADINHA', 'ROCHA CAVALCANTE', 'SANDRA CAVALCANTE', 'SANTA CRUZ',
#         'SANTA ROSA', 'SANTO ANTONIO', 'SAO JOSE', 'SAO JOSE DA MATA',
#         'SERRA DE JOAQUIM VIEIRA', 'SERROTAO', 'SITIO BOI VELHO',
#         'SITIO LUCAS', 'TAMBOR', 'TRES IRMAS', 'VELAME', 'VILA CABRAL',
#         'nan'], dtype=object),
# ...

# %%
df_final2025['BAIRRO'].fillna('JARDIM QUARENTA',inplace=True)
# Out:
# /tmp/ipython-input-2866307632.py:1: FutureWarning:
#
# A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.

# %%
df_final2025['CLASS DOENCA'].value_counts()
# Out:
# CLASS DOENCA
# DENGUE    213
# Name: count, dtype: int64

# %%
df_final2025.to_csv('dengue2025_tratado.csv',index=False)
